# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("ecommerce_discount_data.csv")
data
# Out:
#     Units_Sold  Revenue Discount_Category
# 0            8     5600               Low
# 1           12     8400               Low
# 2           15    10500               Low
# 3           18    12600               Low
# 4           20    14000               Low
# ..         ...      ...               ...
# 85         126    88200              High
# 86         136    95200              High
# 87         146   102200              High
# 88         156   109200              High
# 89         160   112000              High
#
# [90 rows x 3 columns]

# %%
x=data[['Units_Sold','Revenue']]
x
# Out:
#     Units_Sold  Revenue
# 0            8     5600
# 1           12     8400
# 2           15    10500
# 3           18    12600
# 4           20    14000
# ..         ...      ...
# 85         126    88200
# 86         136    95200
# 87         146   102200
# 88         156   109200
# 89         160   112000
#
# [90 rows x 2 columns]

# %%
y=data['Discount_Category']
y
# Out:
# 0      Low
# 1      Low
# 2      Low
# 3      Low
# 4      Low
#       ...
# 85    High
# 86    High
# 87    High
# 88    High
# 89    High
# Name: Discount_Category, Length: 90, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40)

# %%
model=DecisionTreeClassifier(criterion='entropy',random_state=40)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=40)

# %%
y_pred=model.predict(x_test)

# %%
print("Accuracy:",accuracy_score(y_test,y_pred)*100)

cm=confusion_matrix(y_test,y_pred,labels=['Low','Medium','High'])
print(cm)
# Out:
# Accuracy: 100.0
# [[6 0 0]
#  [0 7 0]
#  [0 0 5]]

# %%
plt.imshow(cm,cmap="Greens")
plt.title("Decision Tree Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
unit_sold=int(input("Enter your units:"))
revenue=int(input("Enter your revenue:"))

x1=[[unit_sold,revenue]]
print(model.predict(x1))
# Out:
# Enter your units:12
# Enter your revenue:7400
# ['Low']
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
